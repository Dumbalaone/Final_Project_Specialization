# %% [markdown]
# # 📥 Data Loading & Cleaning

# %% [markdown]
# ## Step 1: Load GBIF occurrence data

# %%
import pandas as pd

# Load GBIF occurrence data (tab-separated)
df = pd.read_csv("occurrence.txt", sep="\t", low_memory=False)

# Preview the first few rows
df.head()
# Out:
#        gbifID  accessRights  bibliographicCitation language       license  \
# 0  3863936945           NaN                    NaN       en  CC_BY_NC_4_0
# 1  3863936944           NaN                    NaN       en  CC_BY_NC_4_0
# 2  3863936943           NaN                    NaN       en  CC_BY_NC_4_0
# 3  3863936942           NaN                    NaN       en  CC_BY_NC_4_0
# 4  3863936941           NaN                    NaN       en  CC_BY_NC_4_0
#
#    modified  publisher  references  rightsHolder  type  ...  \
# 0       NaN        NaN         NaN           NaN   NaN  ...
# 1       NaN        NaN         NaN           NaN   NaN  ...
# 2       NaN        NaN         NaN           NaN   NaN  ...
# 3       NaN        NaN         NaN           NaN   NaN  ...
# 4       NaN        NaN         NaN           NaN   NaN  ...
#
#   publishedByGbifRegion  level0Gid  level0Name level1Gid level1Name  \
# 0                AFRICA        KEN       Kenya  KEN.19_1      Kwale
# 1                AFRICA        KEN       Kenya  KEN.19_1      Kwale
# 2                AFRICA        KEN       Kenya  KEN.19_1      Kwale
# 3                AFRICA        KEN       Kenya  KEN.19_1      Kwale
# 4                AFRICA        KEN       Kenya  KEN.19_1      Kwale
#
#     level2Gid  level2Name     level3Gid       level3Name  iucnRedListCategory
# 0  KEN.19.2_1  Lungalunga  KEN.19.2.3_1  Pongwe/Kikoneni                   LC
# 1  KEN.19.2_1  Lungalunga  KEN.19.2.3_1  Pongwe/Kikoneni                   LC
# 2  KEN.19.1_1     Kinango  KEN.19.1.2_1          Kinango                   LC
# 3  KEN.19.2_1  Lungalunga  KEN.19.2.3_1  Pongwe/Kikoneni                   LC
# 4  KEN.19.2_1  Lungalunga  KEN.19.2.3_1  Pongwe/Kikoneni                   LC
#
# [5 rows x 225 columns]

# %% [markdown]
# ## Step 2: Inspect and select relevant columns

# %%
# Select only useful columns for HWC analysis
columns_to_keep = [
    'scientificName', 'eventDate', 'decimalLatitude', 'decimalLongitude',
    'county', 'stateProvince', 'individualCount', 'basisOfRecord', 'occurrenceStatus'
]

df_clean = df[columns_to_keep].copy()

# Preview cleaned data
df_clean.head()
# Out:
#                 scientificName   eventDate  decimalLatitude  decimalLongitude  \
# 0  Coleura afra (Peters, 1852)  2012-09-23         -4.61532          39.35317
# 1  Coleura afra (Peters, 1852)  2012-09-23         -4.61532          39.35317
# 2  Coleura afra (Peters, 1852)  2012-09-30         -4.08171          39.48295
# 3  Coleura afra (Peters, 1852)  2012-09-23         -4.61532          39.35317
# 4  Coleura afra (Peters, 1852)  2012-09-23         -4.61532          39.35317
#
#   county stateProvince  individualCount       basisOfRecord occurrenceStatus
# 0  Kwale  Kenyan Coast                1  PRESERVED_SPECIMEN          PRESENT
# 1  Kwale  Kenyan Coast                1  PRESERVED_SPECIMEN          PRESENT
# 2  Kwale  Kenyan Coast                1  PRESERVED_SPECIMEN          PRESENT
# 3  Kwale  Kenyan Coast                1  PRESERVED_SPECIMEN          PRESENT
# 4  Kwale  Kenyan Coast                1  PRESERVED_SPECIMEN          PRESENT

# %% [markdown]
# ## Step 3: Handle missing values / duplicates

# %%
# Drop rows without coordinates (important for mapping)
df_clean.dropna(subset=['decimalLatitude', 'decimalLongitude'], inplace=True)

# Optional: Remove duplicates
df_clean.drop_duplicates(inplace=True)

# Optional: Filter by country if necessary
# df_clean = df_clean[df['countryCode'] == 'KE']

# %% [markdown]
# ## Step 4: Save cleaned dataset

# %%
# Save to CSV for use in the next notebooks
df_clean.to_csv("cleaned_gbif_data.csv", index=False)

print("Cleaned dataset saved as 'cleaned_gbif_data.csv'")
# Out:
# Cleaned dataset saved as 'cleaned_gbif_data.csv'
